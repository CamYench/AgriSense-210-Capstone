# %%
import rasterio
from pathlib import Path
import numpy as np

# %%
# change this depending on S3 implementation?
DATA_PATH =Path("local_data")
print(DATA_PATH.exists())
# Out:
# True

# %%
from chl_a import main

# %%
main()
# Out:
# Loaded band specs
# Found files:
#   LC09_L2SP_043035_20240618_20240619_02_T1_SR_B5.tif
#   LC09_L2SP_043035_20240618_20240619_02_T1_SR_B4.tif
#   LC09_L2SP_043035_20240618_20240619_02_T1_SR_B3.tif
# Found files:
#   LC08_L2SP_043035_20240525_20240610_02_T1_SR_B5.tif
#   LC08_L2SP_043035_20240525_20240610_02_T1_SR_B4.tif
#   LC08_L2SP_043035_20240525_20240610_02_T1_SR_B3.tif
# Raw
#   min = 0
#   max = 53384
# 0 --> NAN
#   min = 4062.0
#   max = 53384.0
# Valid
#   min = 7273.0
#   max = 43636.0
# Reflectance
#   min = 7.499999999993623e-06
#   max = 0.9999900000000002
# Raw
#   min = 0
#   max = 52418
# 0 --> NAN
#   min = 1918.0
#   max = 52418.0
# Valid
#   min = 7273.0
#   max = 43636.0
# Reflectance
#   min = 7.499999999993623e-06
#   max = 0.9999900000000002
# Raw
#   min = 0
#   max = 44063
# 0 --> NAN
#   min = 1112.0
#   max = 44063.0
# Valid
#   min = 7273.0
#   max = 43636.0
# Reflectance
#   min = 7.499999999993623e-06
#   max = 0.9999900000000002
# ...

# %%
from rasterio.plot import show

# %%
mtvi2_path = "./local_data/LC09_L2SP_043035_20240618_20240619_02_T1_SR_MTVI2.tif"
mtvi2_datareader = rasterio.open(mtvi2_path)
show(mtvi2_datareader)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

mtvi2_rast_data = rasterio.open(mtvi2_path)

fig, ax = plt.subplots(1,1)
retted = show(mtvi2_rast_data, ax=ax)
im = retted.get_images()[0]
fig.colorbar(im, ax=ax)

# %%
mtvi2_data = mtvi2_datareader.read(1)
mtvi2_data[mtvi2_data.shape[0]//2, mtvi2_data.shape[1]//2]
# Out:
# np.float64(0.12777856022338024)

# %%
mtvi2_data.min()
# Out:
# np.float64(-99999.0)

# %%
mtvi2_data.max()
# Out:
# np.float64(1.3288081217940595)

# %%
mtvi2_data.dtype
# Out:
# dtype('float64')

# %%
mtvi2_datareader.nodata
# Out:
# -99999.0

# %%
mtvi2_datareader.meta
# Out:
# {'driver': 'GTiff',
#  'dtype': 'float64',
#  'nodata': -99999.0,
#  'width': 7601,
#  'height': 7721,
#  'count': 1,
#  'crs': CRS.from_epsg(32610),
#  'transform': Affine(30.0, 0.0, 564885.0,
#         0.0, -30.0, 4105815.0)}
