# %%
import pandas as pd
import requests
import pprint

import urllib.request

from pathlib import Path

# %%
# this dataset describes the metadata for each image in Landsat 9 (i think 9...)

# download this file from here:
# https://landsat.usgs.gov/landsat/metadata_service/bulk_metadata_files/LANDSAT_OT_C2_L2.csv.gz
# and extract...
# Will take a while. There is a "bulk metadata api" that describes all the images available that will replace the above file
# more info here:
# https://www.usgs.gov/landsat-missions/bulk-metadata-service


path = "./metadata/LANDSAT_OT_C2_L2.csv"
data = pd.read_csv(path)

# %%
# some conditions defining "California"
# we want to get all images that capture california
ca_min_lat = 32.5
ca_max_lat = 42
ca_min_lon = -124.5
ca_max_lon = -114.0

# define condtitions

# corner upper left
CUL_LAT = (data["Corner Upper Left Latitude"] >= ca_min_lat) & (data["Corner Upper Left Latitude"] <= ca_max_lat)
CUL_LON = (data["Corner Upper Left Longitude"] >= ca_min_lon) & (data["Corner Upper Left Longitude"] <= ca_max_lon)

# corner upper right
CUR_LAT = (data["Corner Upper Right Latitude"] >= ca_min_lat) & (data["Corner Upper Right Latitude"] <= ca_max_lat)
CUR_LON = (data["Corner Upper Right Longitude"] >= ca_min_lon) & (data["Corner Upper Right Longitude"] <= ca_max_lon)

# corner lower left
CLL_LAT = (data["Corner Lower Left Latitude"] >= ca_min_lat) & (data["Corner Lower Left Latitude"] <= ca_max_lat)
CLL_LON = (data["Corner Lower Left Longitude"] >= ca_min_lon) & (data["Corner Lower Left Longitude"] <= ca_max_lon)

# corner lower right
CLR_LAT = (data["Corner Lower Right Latitude"] >= ca_min_lat) & (data["Corner Lower Right Latitude"] <= ca_max_lat)
CLR_LON = (data["Corner Lower Right Longitude"] >= ca_min_lon) & (data["Corner Lower Right Longitude"] <= ca_max_lon)


# ca_data = data[(CUL_LAT & CUL_LON) | (CUR_LAT & CUR_LON ) | (CLL_LAT & CLL_LON) | (CLR_LAT & CLR_LON)]
ca_data = data[(data["Scene Center Latitude"] >= ca_min_lat) & (data["Scene Center Latitude"] <= ca_max_lat) & 
               (data["Scene Center Longitude"] >= ca_min_lon) & (data["Scene Center Longitude"] <= ca_max_lon)]

# %%
# some conditions defining "Monterey Sample Area"
# we want to get all images that capture monterey
monterey_min_lat = 35.787773
monterey_max_lat = 36.914796
monterey_min_lon = -121.973412
monterey_max_lon = -120.211479

# define condtitions

# corner upper left
CUL_LAT = (data["Corner Upper Left Latitude"] >= monterey_min_lat) & (data["Corner Upper Left Latitude"] <= monterey_max_lat)
CUL_LON = (data["Corner Upper Left Longitude"] >= monterey_min_lon) & (data["Corner Upper Left Longitude"] <= monterey_max_lon)

# corner upper right
CUR_LAT = (data["Corner Upper Right Latitude"] >= monterey_min_lat) & (data["Corner Upper Right Latitude"] <= monterey_max_lat)
CUR_LON = (data["Corner Upper Right Longitude"] >= monterey_min_lon) & (data["Corner Upper Right Longitude"] <= monterey_max_lon)

# corner lower left
CLL_LAT = (data["Corner Lower Left Latitude"] >= monterey_min_lat) & (data["Corner Lower Left Latitude"] <= monterey_max_lat)
CLL_LON = (data["Corner Lower Left Longitude"] >= monterey_min_lon) & (data["Corner Lower Left Longitude"] <= monterey_max_lon)

# corner lower right
CLR_LAT = (data["Corner Lower Right Latitude"] >= monterey_min_lat) & (data["Corner Lower Right Latitude"] <= monterey_max_lat)
CLR_LON = (data["Corner Lower Right Longitude"] >= monterey_min_lon) & (data["Corner Lower Right Longitude"] <= monterey_max_lon)


# monterey_data = data[(CUL_LAT & CUL_LON) | (CUR_LAT & CUR_LON ) | (CLL_LAT & CLL_LON) | (CLR_LAT & CLR_LON)]
monterey_data = data[(data["Scene Center Latitude"] >= monterey_min_lat) & (data["Scene Center Latitude"] <= monterey_max_lat) & 
               (data["Scene Center Longitude"] >= monterey_min_lon) & (data["Scene Center Longitude"] <= monterey_max_lon)]


# specific_lat = 35.853
# specific_lon = -119.343

# specific_lat = 36.297
# specific_lon = -119.648

# specific_lat = 35.875503
# specific_lon = -119.576063

# monterey_data = data[
#     (data["Corner Upper Right Latitude"] >= specific_lat | data["Corner Upper Left Latitude"] >= specific_lat) & 
#     (specific_lat >= data["Corner Lower Right Latitude"]) &
#     (data["Corner Upper Right Longitude"] >= specific_lon) & ( specific_lon >= data["Corner Lower Right Longitude"])
#     ]

# %%
monterey_display_ids=ca_data[
    (ca_data["Scene Center Latitude"] < 37) & (ca_data["Scene Center Latitude"] > 36) &
    (ca_data["Scene Center Longitude"] > -122.1) & (ca_data["Scene Center Longitude"] < -121.0)
    ]["Display ID"].to_list()

# ca_display_ids=ca_data["Display ID"].to_list()

# %%
len(monterey_display_ids)
# Out:
# 103

# %%
API_HOST = "https://espa.cr.usgs.gov/api/v1"
USERNAME="pascualeley"
PASSWORD=input()

# %% [markdown]
# ## Datasets
#
# ### NASA EarthData - [Agriculture](https://www.earthdata.nasa.gov/learn/pathfinders/agricultural-and-water-resources-data-pathfinder)
#
# ### Landsat Collection 2 - Surface Reflectance-derived Spectral Indices - [Overview](https://www.usgs.gov/landsat-missions/landsat-surface-reflectance-derived-spectral-indices)
#
# Use the [M2M Api](https://m2m.cr.usgs.gov/) or the Bulk Downloader
#
#
# - Normalized Difference Vegetation Index - (NDVI)
#     - NDVI measures "healthy vegetation" by taking the difference in between near-infrared (reflected) and red (absored) light.
# - Enhanced Soil Vegetation Index (EVI)
#     - Similar to NDVI, but also corrects for *atmospheric conditions* and *canopy background noise*.
#     - More sensitive to dense vegetation areas
# - Soil Adjusted Vegetation Index (SAVI)
#     - Applies corrections to NDVI for the influence of *soil brightness* in areas where vegetation cover is low.
# - Modified Soil Adjusted Vegetation Index (MSAVI)
#     - Minimizes the effect of *bare soil* from the SAVI
# - Normalized Difference Moisture Index (NDMI)
#     - determines vegetation water content
# - Dynamic Surface Water Extent (don't think we need this actually...)
#     - provides information about the present and condition of surface water.
# - Surface Temperature
#     - temperature of surface is important indicator of crop and vegetation health.
#
# ### EROS satellite
# - eVIIRS GLOBAL

# %%
def request_data(url:str, json:bool=True, body:dict|None=None, method:str="get"):  
    print("Sending request:")
    print(url)
    if method == "get":
        resp = requests.get(url, auth=(USERNAME, PASSWORD), json=body)
    elif method == "post":
        resp = requests.post(url, auth=(USERNAME, PASSWORD), json=body)
    elif method == "put":
        resp = requests.put(url, auth=(USERNAME, PASSWORD), json=body)
    else:
        return "METHOD NOT SUPPORTED"

    if json:
        return resp.json()
    else:
        return resp

# %%
# endpoint = "/"
# response = requests.get(API_HOST + endpoint)
# print(response.text)
# Out:
# {"messages":{"errors":["Invalid username/password"]}}

# %%
endpoint = "/"
data = request_data(API_HOST + endpoint)
pprint.pprint(data)
# Out:
# Sending request:
# https://espa.cr.usgs.gov/api/v1/
# {'description': 'Version 1 of the ESPA API',
#  'operations': {'/api': {'function': 'list versions',
#                          'methods': ['HEAD', 'GET']},
#                 '/api/v1': {'function': 'list operations',
#                             'methods': ['HEAD', 'GET']},
#                 '/api/v1/available-products': {'comments': 'sceneids should be '
#                                                            'delivered in the '
#                                                            'product_ids '
#                                                            'parameter, comma '
#                                                            'separated if more '
#                                                            'than one',
#                                                'function': 'list available '
#                                                            'products per '
#                                                            'sceneid',
#                                                'methods': ['HEAD', 'POST']},
#                 '/api/v1/available-products/<product_ids>': {'comments': 'comma '
#                                                                          'separated '
#                                                                          'ids '
#                                                                          'supported',
#                                                              'function': 'list '
#                                                                          'available '
#                                                                          'products '
#                                                                          'per '
#                                                                          'sceneid',
#                                                              'methods': ['HEAD',
#                                                                          'GET']},
#                 '/api/v1/formats': {'function': 'list available output formats',
#                                     'methods': ['HEAD', 'GET']},
#                 '/api/v1/list-orders': {'function': 'list orders for '
#                                                     'authenticated user',
#                                         'methods': ['HEAD', 'GET']},
#                 '/api/v1/list-orders/<email>': {'function': 'list orders for '
#                                                             'supplied email, '
#                                                             'for user '
#                                                             'collaboration',
#                                                 'methods': ['HEAD', 'GET']},
#                 '/api/v1/order': {'function': 'point for accepting processing '
#                                               'requests via HTTP POST with '
#                                               'JSON body. Errors are returned '
#                                               'to user, successful validation '
#                                               'returns an orderid',
#                                   'methods': ['POST']},
#                 '/api/v1/order/<ordernum>': {'function': 'retrieves a '
#                                                          'submitted order',
#                                              'methods': ['HEAD', 'GET']},
#                 '/api/v1/projections': {'function': 'list available '
#                                                     'projections',
#                                         'methods': ['HEAD', 'GET']},
#                 '/api/v1/resampling-methods': {'function': 'list available '
#                                                            'resampling methods',
#                                                'methods': ['HEAD', 'GET']}}}

# %%
#default example
# display_id = "LC08_L2SP_042033_20200912_20200919_02_T1"

#monterey example
display_id = "LC09_L2SP_043035_20211121_20230407_02_T1"
print(ca_data[ca_data['Display ID'] == display_id])
print(ca_data[ca_data['Display ID'] == display_id]['Date Acquired'].max())
# Out:
#                                                Browse Link  \
# 2354400  https://landsatlook.usgs.gov/gen-browse?size=r...
#
#                                        Display ID            Ordering ID  \
# 2354400  LC09_L2SP_043035_20211121_20230407_02_T1  LC90430352021325LGN04
#
#                     Landsat Product Identifier L2  \
# 2354400  LC09_L2SP_043035_20211121_20230407_02_T1
#
#                     Landsat Product Identifier L1 Landsat Scene Identifier  \
# 2354400  LC09_L1TP_043035_20211121_20230407_02_T1    LC90430352021325LGN04
#
#         Date Acquired Collection Category  Collection Number  WRS Path  ...  \
# 2354400    2021/11/21                  T1                  2        43  ...
#
#          Scene Center Latitude  Scene Center Longitude  \
# 2354400               36.04317              -121.64178
#
#          Corner Upper Left Latitude Corner Upper Left Longitude  \
# 2354400                    37.09576                   -122.8976
#
#          Corner Upper Right Latitude Corner Upper Right Longitude  \
# 2354400                     37.06619                   -120.35006
#
#         Corner Lower Left Latitude Corner Lower Left Longitude  \
# 2354400                   34.99687                  -122.90028
#
#         Corner Lower Right Latitude Corner Lower Right Longitude
# 2354400                    34.96947                   -120.41939
#
# [1 rows x 49 columns]
# 2021/11/21

# %%
endpoint = "/available-products"
# avail_list = {
#     "inputs": [
#         "LE07_L2SP_038034_20050424_20200914_02_T2"
#     ]
# }
avail_list = {
    "inputs": [display_id] 
}
data = request_data(API_HOST + endpoint, body=avail_list)
pprint.pprint(data)
# Out:
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# {'olitirs9_collection_2_l2': {'inputs': ['LC09_L2SP_043035_20211121_20230407_02_T1'],
#                               'products': ['l1',
#                                            'sr_ndvi',
#                                            'sr_evi',
#                                            'sr_savi',
#                                            'sr_msavi',
#                                            'sr_ndmi',
#                                            'sr_nbr',
#                                            'sr_nbr2',
#                                            'sr_ndsi',
#                                            'et']}}

# %%
def update_nested_key(data, target_key, new_value):
    if isinstance(data, dict):
        for key, value in data.items():
            if key == target_key:
                data[key] = new_value
            elif isinstance(value, dict):
                update_nested_key(value, target_key, new_value)
            elif isinstance(value, list):
                for item in value:
                    update_nested_key(item, target_key, new_value)
    elif isinstance(data, list):
        for item in data:
            update_nested_key(item, target_key, new_value)

# %%
# now do the above for all landsat images (UPDATED TO PULL more products)

for display_id in monterey_display_ids:
    
    endpoint = "/available-products"
    avail_list = {
        "inputs": [display_id] 
    }
    data = request_data(API_HOST + endpoint, body=avail_list)

    endpoint = "/order"
    data['format'] = 'gtiff'
    update_nested_key(data, 'products', ['l1','sr_ndmi','et'])
    resp = request_data(API_HOST + endpoint, body=data, method="post")
    pprint.pprint(resp)
# Out:
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002124-871',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002129-409',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002131-786',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002133-892',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002137-797',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002140-338',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002146-541',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002150-219',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002159-009',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002203-164',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002211-963',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002228-751',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002235-951',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002239-748',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002244-189',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002248-917',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002254-917',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002259-711',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002302-650',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002305-374',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002308-285',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002310-607',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002313-015',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002315-021',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002317-681',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002320-018',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002323-177',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002325-382',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002328-396',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002331-282',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002333-993',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002337-013',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002339-762',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002342-525',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002346-274',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002349-774',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002352-654',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002356-283',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002359-360',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002402-558',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002406-573',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002410-041',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002415-139',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002419-157',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002422-311',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002424-962',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002427-424',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002430-207',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002434-040',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002436-681',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002439-875',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002442-486',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002445-537',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002447-604',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002450-164',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002452-144',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002454-579',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002456-392',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002458-559',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002500-692',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002504-093',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002506-033',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002508-247',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002510-388',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002512-693',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002514-612',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002516-601',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002518-721',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002521-108',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002523-093',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002525-520',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002527-736',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002529-914',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002532-783',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002535-000',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002537-479',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002540-825',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002543-382',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002546-343',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002550-018',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002553-557',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002556-600',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002600-161',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002603-233',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002607-768',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002611-560',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002614-655',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002618-118',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002620-684',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002624-113',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002626-736',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002630-271',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002633-188',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002636-173',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002638-986',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002641-023',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002642-924',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002645-113',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002646-811',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002648-489',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002650-546',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002652-741',
#  'status': 'ordered'}
# Sending request:
# https://espa.cr.usgs.gov/api/v1/available-products
# Sending request:
# https://espa.cr.usgs.gov/api/v1/order
# {'orderid': 'espa-pascualeley@gmail.com-07042024-002654-603',
#  'status': 'ordered'}

# %%
# get all orders

endpoint = "/list-orders"

all_orders = request_data(API_HOST + endpoint)
pprint.pprint(all_orders)
# Out:
# Sending request:
# https://espa.cr.usgs.gov/api/v1/list-orders
# ['espa-pascualeley@gmail.com-07042024-002654-603',
#  'espa-pascualeley@gmail.com-07042024-002652-741',
#  'espa-pascualeley@gmail.com-07042024-002650-546',
#  'espa-pascualeley@gmail.com-07042024-002648-489',
#  'espa-pascualeley@gmail.com-07042024-002646-811',
#  'espa-pascualeley@gmail.com-07042024-002645-113',
#  'espa-pascualeley@gmail.com-07042024-002642-924',
#  'espa-pascualeley@gmail.com-07042024-002641-023',
#  'espa-pascualeley@gmail.com-07042024-002638-986',
#  'espa-pascualeley@gmail.com-07042024-002636-173',
#  'espa-pascualeley@gmail.com-07042024-002633-188',
#  'espa-pascualeley@gmail.com-07042024-002630-271',
#  'espa-pascualeley@gmail.com-07042024-002626-736',
#  'espa-pascualeley@gmail.com-07042024-002624-113',
#  'espa-pascualeley@gmail.com-07042024-002620-684',
#  'espa-pascualeley@gmail.com-07042024-002618-118',
#  'espa-pascualeley@gmail.com-07042024-002614-655',
#  'espa-pascualeley@gmail.com-07042024-002611-560',
#  'espa-pascualeley@gmail.com-07042024-002607-768',
#  'espa-pascualeley@gmail.com-07042024-002603-233',
#  'espa-pascualeley@gmail.com-07042024-002600-161',
#  'espa-pascualeley@gmail.com-07042024-002556-600',
#  'espa-pascualeley@gmail.com-07042024-002553-557',
#  'espa-pascualeley@gmail.com-07042024-002550-018',
#  'espa-pascualeley@gmail.com-07042024-002546-343',
#  'espa-pascualeley@gmail.com-07042024-002543-382',
#  'espa-pascualeley@gmail.com-07042024-002540-825',
#  'espa-pascualeley@gmail.com-07042024-002537-479',
#  'espa-pascualeley@gmail.com-07042024-002535-000',
#  'espa-pascualeley@gmail.com-07042024-002532-783',
#  'espa-pascualeley@gmail.com-07042024-002529-914',
#  'espa-pascualeley@gmail.com-07042024-002527-736',
#  'espa-pascualeley@gmail.com-07042024-002525-520',
#  'espa-pascualeley@gmail.com-07042024-002523-093',
#  'espa-pascualeley@gmail.com-07042024-002521-108',
#  'espa-pascualeley@gmail.com-07042024-002518-721',
#  'espa-pascualeley@gmail.com-07042024-002516-601',
#  'espa-pascualeley@gmail.com-07042024-002514-612',
#  'espa-pascualeley@gmail.com-07042024-002512-693',
#  'espa-pascualeley@gmail.com-07042024-002510-388',
#  'espa-pascualeley@gmail.com-07042024-002508-247',
#  'espa-pascualeley@gmail.com-07042024-002506-033',
#  'espa-pascualeley@gmail.com-07042024-002504-093',
#  'espa-pascualeley@gmail.com-07042024-002500-692',
#  'espa-pascualeley@gmail.com-07042024-002458-559',
#  'espa-pascualeley@gmail.com-07042024-002456-392',
#  'espa-pascualeley@gmail.com-07042024-002454-579',
#  'espa-pascualeley@gmail.com-07042024-002452-144',
#  'espa-pascualeley@gmail.com-07042024-002450-164',
#  'espa-pascualeley@gmail.com-07042024-002447-604',
#  'espa-pascualeley@gmail.com-07042024-002445-537',
#  'espa-pascualeley@gmail.com-07042024-002442-486',
#  'espa-pascualeley@gmail.com-07042024-002439-875',
#  'espa-pascualeley@gmail.com-07042024-002436-681',
#  'espa-pascualeley@gmail.com-07042024-002434-040',
#  'espa-pascualeley@gmail.com-07042024-002430-207',
#  'espa-pascualeley@gmail.com-07042024-002427-424',
#  'espa-pascualeley@gmail.com-07042024-002424-962',
#  'espa-pascualeley@gmail.com-07042024-002422-311',
#  'espa-pascualeley@gmail.com-07042024-002419-157',
#  'espa-pascualeley@gmail.com-07042024-002415-139',
#  'espa-pascualeley@gmail.com-07042024-002410-041',
#  'espa-pascualeley@gmail.com-07042024-002406-573',
#  'espa-pascualeley@gmail.com-07042024-002402-558',
#  'espa-pascualeley@gmail.com-07042024-002359-360',
#  'espa-pascualeley@gmail.com-07042024-002356-283',
#  'espa-pascualeley@gmail.com-07042024-002352-654',
#  'espa-pascualeley@gmail.com-07042024-002349-774',
#  'espa-pascualeley@gmail.com-07042024-002346-274',
#  'espa-pascualeley@gmail.com-07042024-002342-525',
#  'espa-pascualeley@gmail.com-07042024-002339-762',
#  'espa-pascualeley@gmail.com-07042024-002337-013',
#  'espa-pascualeley@gmail.com-07042024-002333-993',
#  'espa-pascualeley@gmail.com-07042024-002331-282',
#  'espa-pascualeley@gmail.com-07042024-002328-396',
#  'espa-pascualeley@gmail.com-07042024-002325-382',
#  'espa-pascualeley@gmail.com-07042024-002323-177',
#  'espa-pascualeley@gmail.com-07042024-002320-018',
#  'espa-pascualeley@gmail.com-07042024-002317-681',
#  'espa-pascualeley@gmail.com-07042024-002315-021',
#  'espa-pascualeley@gmail.com-07042024-002313-015',
#  'espa-pascualeley@gmail.com-07042024-002310-607',
#  'espa-pascualeley@gmail.com-07042024-002308-285',
#  'espa-pascualeley@gmail.com-07042024-002305-374',
#  'espa-pascualeley@gmail.com-07042024-002302-650',
#  'espa-pascualeley@gmail.com-07042024-002259-711',
#  'espa-pascualeley@gmail.com-07042024-002254-917',
#  'espa-pascualeley@gmail.com-07042024-002248-917',
#  'espa-pascualeley@gmail.com-07042024-002244-189',
#  'espa-pascualeley@gmail.com-07042024-002239-748',
#  'espa-pascualeley@gmail.com-07042024-002235-951',
#  'espa-pascualeley@gmail.com-07042024-002228-751',
#  'espa-pascualeley@gmail.com-07042024-002211-963',
#  'espa-pascualeley@gmail.com-07042024-002203-164',
#  'espa-pascualeley@gmail.com-07042024-002159-009',
#  'espa-pascualeley@gmail.com-07042024-002150-219',
#  'espa-pascualeley@gmail.com-07042024-002146-541',
#  'espa-pascualeley@gmail.com-07042024-002140-338',
#  'espa-pascualeley@gmail.com-07042024-002137-797',
#  'espa-pascualeley@gmail.com-07042024-002133-892',
#  'espa-pascualeley@gmail.com-07042024-002131-786',
#  'espa-pascualeley@gmail.com-07042024-002129-409',
#  'espa-pascualeley@gmail.com-07042024-002124-871',
#  'espa-pascualeley@gmail.com-06172024-231045-816',
#  'espa-pascualeley@gmail.com-06172024-231047-917',
#  'espa-pascualeley@gmail.com-06172024-231049-206',
#  'espa-pascualeley@gmail.com-06172024-231050-491',
#  'espa-pascualeley@gmail.com-06172024-231051-806',
#  'espa-pascualeley@gmail.com-06172024-231053-097',
#  'espa-pascualeley@gmail.com-06172024-231054-378',
#  'espa-pascualeley@gmail.com-06172024-231055-759',
#  'espa-pascualeley@gmail.com-06172024-231057-090',
#  'espa-pascualeley@gmail.com-06172024-231058-479',
#  'espa-pascualeley@gmail.com-06172024-231059-719',
#  'espa-pascualeley@gmail.com-06172024-231101-095',
#  'espa-pascualeley@gmail.com-06172024-231102-527',
#  'espa-pascualeley@gmail.com-06172024-231104-040',
#  'espa-pascualeley@gmail.com-06172024-231105-336',
#  'espa-pascualeley@gmail.com-06172024-231106-600',
#  'espa-pascualeley@gmail.com-06172024-231107-907',
#  'espa-pascualeley@gmail.com-06172024-231109-236',
#  'espa-pascualeley@gmail.com-06172024-231110-580',
#  'espa-pascualeley@gmail.com-06172024-231111-900',
#  'espa-pascualeley@gmail.com-06172024-231113-290',
#  'espa-pascualeley@gmail.com-06172024-231114-601',
#  'espa-pascualeley@gmail.com-06172024-231115-962',
#  'espa-pascualeley@gmail.com-06172024-231117-297',
#  'espa-pascualeley@gmail.com-06172024-231118-605',
#  'espa-pascualeley@gmail.com-06172024-231119-908',
#  'espa-pascualeley@gmail.com-06172024-231121-150',
#  'espa-pascualeley@gmail.com-06172024-231122-447',
#  'espa-pascualeley@gmail.com-06172024-231123-752',
#  'espa-pascualeley@gmail.com-06172024-231125-055',
#  'espa-pascualeley@gmail.com-06172024-231126-385',
#  'espa-pascualeley@gmail.com-06172024-231127-685',
#  'espa-pascualeley@gmail.com-06172024-231129-092',
#  'espa-pascualeley@gmail.com-06172024-231130-373',
#  'espa-pascualeley@gmail.com-06172024-231131-670',
#  'espa-pascualeley@gmail.com-06172024-231132-987',
#  'espa-pascualeley@gmail.com-06172024-231134-455',
#  'espa-pascualeley@gmail.com-06172024-231135-781',
#  'espa-pascualeley@gmail.com-06172024-231137-101',
#  'espa-pascualeley@gmail.com-06172024-231138-472',
#  'espa-pascualeley@gmail.com-06172024-231139-796',
#  'espa-pascualeley@gmail.com-06172024-231141-130',
#  'espa-pascualeley@gmail.com-06172024-231142-424',
#  'espa-pascualeley@gmail.com-06172024-231143-743',
#  'espa-pascualeley@gmail.com-06172024-231145-110',
#  'espa-pascualeley@gmail.com-06172024-231146-596',
#  'espa-pascualeley@gmail.com-06172024-231147-974',
#  'espa-pascualeley@gmail.com-06172024-231149-236',
#  'espa-pascualeley@gmail.com-06172024-231150-512',
#  'espa-pascualeley@gmail.com-06172024-231151-796',
#  'espa-pascualeley@gmail.com-06172024-231153-131',
#  'espa-pascualeley@gmail.com-06172024-231154-503',
#  'espa-pascualeley@gmail.com-06172024-231155-876',
#  'espa-pascualeley@gmail.com-06172024-231157-248',
#  'espa-pascualeley@gmail.com-06172024-231158-620',
#  'espa-pascualeley@gmail.com-06172024-231159-926',
#  'espa-pascualeley@gmail.com-06172024-231201-233',
#  'espa-pascualeley@gmail.com-06172024-231202-684',
#  'espa-pascualeley@gmail.com-06172024-231204-078',
#  'espa-pascualeley@gmail.com-06172024-231205-449',
#  'espa-pascualeley@gmail.com-06172024-231206-816',
#  'espa-pascualeley@gmail.com-06172024-231208-140',
#  'espa-pascualeley@gmail.com-06172024-231209-584',
#  'espa-pascualeley@gmail.com-06172024-231211-054',
#  'espa-pascualeley@gmail.com-06172024-231212-424',
#  'espa-pascualeley@gmail.com-06172024-231213-839',
#  'espa-pascualeley@gmail.com-06172024-231215-460',
#  'espa-pascualeley@gmail.com-06172024-231216-902',
#  'espa-pascualeley@gmail.com-06172024-231218-344',
#  'espa-pascualeley@gmail.com-06172024-231219-781',
#  'espa-pascualeley@gmail.com-06172024-231221-173',
#  'espa-pascualeley@gmail.com-06172024-231222-577',
#  'espa-pascualeley@gmail.com-06172024-231224-027',
#  'espa-pascualeley@gmail.com-06172024-231225-518',
#  'espa-pascualeley@gmail.com-06172024-231226-870',
#  'espa-pascualeley@gmail.com-06172024-231228-208',
#  'espa-pascualeley@gmail.com-06172024-231229-610',
#  'espa-pascualeley@gmail.com-06172024-231231-076',
#  'espa-pascualeley@gmail.com-06172024-231232-442',
#  'espa-pascualeley@gmail.com-06172024-231233-893',
#  'espa-pascualeley@gmail.com-06172024-231235-412',
#  'espa-pascualeley@gmail.com-06172024-231236-715',
#  'espa-pascualeley@gmail.com-06172024-231238-158',
#  'espa-pascualeley@gmail.com-06172024-231239-538',
#  'espa-pascualeley@gmail.com-06172024-231240-875',
#  'espa-pascualeley@gmail.com-06172024-231242-233',
#  'espa-pascualeley@gmail.com-06172024-231243-838',
#  'espa-pascualeley@gmail.com-06172024-231245-233',
#  'espa-pascualeley@gmail.com-06172024-231246-678',
#  'espa-pascualeley@gmail.com-06172024-231247-989',
#  'espa-pascualeley@gmail.com-06172024-231249-360',
#  'espa-pascualeley@gmail.com-06172024-231250-714',
#  'espa-pascualeley@gmail.com-06172024-231252-018',
#  'espa-pascualeley@gmail.com-06172024-231253-669',
#  'espa-pascualeley@gmail.com-06172024-231255-349',
#  'espa-pascualeley@gmail.com-06172024-231257-266',
#  'espa-pascualeley@gmail.com-06172024-231258-951',
#  'espa-pascualeley@gmail.com-06172024-231300-590',
#  'espa-pascualeley@gmail.com-06172024-231302-097',
#  'espa-pascualeley@gmail.com-06172024-231303-465',
#  'espa-pascualeley@gmail.com-06172024-231304-921',
#  'espa-pascualeley@gmail.com-06172024-231306-349',
#  'espa-pascualeley@gmail.com-06172024-231307-748',
#  'espa-pascualeley@gmail.com-06172024-225057-595',
#  'espa-pascualeley@gmail.com-06152024-005433-998',
#  'espa-pascualeley@gmail.com-06152024-005552-378',
#  'espa-pascualeley@gmail.com-06152024-005553-616',
#  'espa-pascualeley@gmail.com-06152024-005554-865',
#  'espa-pascualeley@gmail.com-06152024-010022-776',
#  'espa-pascualeley@gmail.com-06152024-010024-031',
#  'espa-pascualeley@gmail.com-06152024-010025-564',
#  'espa-pascualeley@gmail.com-06152024-010027-034',
#  'espa-pascualeley@gmail.com-06152024-001515-339',
#  'espa-pascualeley@gmail.com-06152024-001636-978',
#  'espa-pascualeley@gmail.com-06152024-001638-151',
#  'espa-pascualeley@gmail.com-06152024-001639-324']

# %%
#add order filter code block
def filter_list_by_string(input_list, filter_string):
    return [item for item in input_list if filter_string in item]

# %%
# filter for only orders made on target day
#CHANGE string to current date if re-running script!
all_orders_filtered = filter_list_by_string(all_orders, '07042024')

# %%
# get download link for all finished orders
# GIVE TIME FOR ORDERS TO BE FINISHED

order_dict = {}
i=0

for orderid in all_orders_filtered:

    # get status first
    endpoint = f"/item-status/{orderid}"
    resp = request_data(API_HOST + endpoint)
    # pprint.pprint(resp)
    print(i)
    i+=1
    for product in resp[orderid]:

        if product["status"] == "complete":
            download_url = product["product_dload_url"]
            name = product["name"]
            order_dict[orderid] = {'name':name,'download_url':download_url,'year':ca_data[ca_data['Display ID'] == name]['Date Acquired'].max()}
# Out:
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002654-603
# 0
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002652-741
# 1
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002650-546
# 2
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002648-489
# 3
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002646-811
# 4
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002645-113
# 5
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002642-924
# 6
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002641-023
# 7
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002638-986
# 8
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002636-173
# 9
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002633-188
# 10
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002630-271
# 11
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002626-736
# 12
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002624-113
# 13
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002620-684
# 14
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002618-118
# 15
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002614-655
# 16
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002611-560
# 17
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002607-768
# 18
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002603-233
# 19
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002600-161
# 20
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002556-600
# 21
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002553-557
# 22
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002550-018
# 23
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002546-343
# 24
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002543-382
# 25
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002540-825
# 26
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002537-479
# 27
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002535-000
# 28
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002532-783
# 29
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002529-914
# 30
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002527-736
# 31
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002525-520
# 32
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002523-093
# 33
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002521-108
# 34
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002518-721
# 35
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002516-601
# 36
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002514-612
# 37
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002512-693
# 38
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002510-388
# 39
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002508-247
# 40
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002506-033
# 41
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002504-093
# 42
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002500-692
# 43
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002458-559
# 44
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002456-392
# 45
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002454-579
# 46
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002452-144
# 47
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002450-164
# 48
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002447-604
# 49
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002445-537
# 50
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002442-486
# 51
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002439-875
# 52
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002436-681
# 53
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002434-040
# 54
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002430-207
# 55
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002427-424
# 56
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002424-962
# 57
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002422-311
# 58
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002419-157
# 59
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002415-139
# 60
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002410-041
# 61
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002406-573
# 62
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002402-558
# 63
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002359-360
# 64
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002356-283
# 65
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002352-654
# 66
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002349-774
# 67
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002346-274
# 68
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002342-525
# 69
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002339-762
# 70
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002337-013
# 71
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002333-993
# 72
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002331-282
# 73
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002328-396
# 74
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002325-382
# 75
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002323-177
# 76
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002320-018
# 77
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002317-681
# 78
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002315-021
# 79
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002313-015
# 80
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002310-607
# 81
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002308-285
# 82
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002305-374
# 83
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002302-650
# 84
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002259-711
# 85
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002254-917
# 86
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002248-917
# 87
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002244-189
# 88
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002239-748
# 89
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002235-951
# 90
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002228-751
# 91
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002211-963
# 92
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002203-164
# 93
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002159-009
# 94
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002150-219
# 95
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002146-541
# 96
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002140-338
# 97
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002137-797
# 98
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002133-892
# 99
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002131-786
# 100
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002129-409
# 101
# Sending request:
# https://espa.cr.usgs.gov/api/v1/item-status/espa-pascualeley@gmail.com-07042024-002124-871
# 102

# %%
for order_id, order_details in order_dict.items():
    if 'year' in order_details and isinstance(order_details['year'], str):
        order_details['year'] = order_details['year'].replace('/', '.')

# %%
#download orders by download url

county = 'Monterey'
for order in order_dict:
    name=order_dict[order]['name']
    download_url=order_dict[order]['download_url']
    date=order_dict[order]['year']
    print(name)
    print(download_url)
    print(date)

    data_dir = Path("./data/landsat_monterey")
    data_dir.mkdir(exist_ok=True)
    urllib.request.urlretrieve(download_url,data_dir / f"{county}_{date}_{name}.tar.gz" )
# Out:
# LC08_L2SP_043035_20171029_20200902_02_T1
# https://edclpdsftp.cr.usgs.gov/orders/espa-pascualeley@gmail.com-07042024-